# %% [markdown]
# ## Modelling Neural Networks and Evaluation - Part 05
#
# **Neural Networks to Try:**
# + `Feedforward Neural Network (FNN)`: A basic neural network with fully connected (dense) layers.
# + `Deep Neural Network (DNN)`: A deeper version of a feedforward network with more hidden layers.
# + `Convolutional Neural Network (CNN)`: Typically used for image data but can sometimes be applied to tabular data to learn hierarchical feature representations.
# + `Recurrent Neural Network (RNN) / LSTM`: Used for sequential data; if your dataset has a time-series component, this could be valuable.
# + `TabNet or Transformer-Based Models`: Advanced models specifically designed for tabular data, which combine attention mechanisms and other novel architectures.

# %% [markdown]
# ### Feedforward Neural Network

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout, Conv1D, Flatten
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# #### 1. Data Preprocessing: Encoding and Scaling

# %%
# Load your dataset
data = pd.read_csv('no_missing_values_customer_data.csv')

# Convert the target variable 'Churn' to numeric
data['Churn'] = data['Churn'].map({'Yes': 1, 'No': 0})

# Encode categorical variables using one-hot encoding
data_encoded = pd.get_dummies(data.drop(['customerID'], axis=1))

# Separate features and target
features = data_encoded.drop('Churn', axis=1)
target = data_encoded['Churn']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Scaling Methods
# # 1. Standard Scaler
# scaler_standard = StandardScaler()
# X_train_standard = scaler_standard.fit_transform(X_train)
# X_test_standard = scaler_standard.transform(X_test)

# 2. Min-Max Scaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Convert labels to categorical one-hot encoding for neural network
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# %% [markdown]
# #### 2. Model Training with Min Max Scaling

# %%
# Build the Feedforward Neural Network (FNN) model with Min-Max Scaler
model = Sequential()
model.add(Input(shape=(X_train_scaled.shape[1],)))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(2, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', 
                     optimizer='adam', 
                     metrics=['accuracy'])

# Train the model
history = model.fit(X_train_scaled, 
                    y_train_categorical, 
                    epochs=100, 
                    batch_size=32, 
                    validation_data=(X_test_scaled, y_test_categorical), 
                    verbose=1)

# Evaluate the model
y_pred = model.predict(X_test_scaled)
y_pred_classes = np.argmax(y_pred, axis=1)
print("Classification Report for Neural Network with Min-Max Scaler:\n", classification_report(y_test, y_pred_classes))
# Out:
# Epoch 1/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.6662 - loss: 0.6045 - val_accuracy: 0.7942 - val_loss: 0.4219
# Epoch 2/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7744 - loss: 0.4619 - val_accuracy: 0.8119 - val_loss: 0.4101
# Epoch 3/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7854 - loss: 0.4497 - val_accuracy: 0.8126 - val_loss: 0.4092
# Epoch 4/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8046 - loss: 0.4342 - val_accuracy: 0.8133 - val_loss: 0.4111
# Epoch 5/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7864 - loss: 0.4424 - val_accuracy: 0.8141 - val_loss: 0.4059
# Epoch 6/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7957 - loss: 0.4248 - val_accuracy: 0.8119 - val_loss: 0.4035
# Epoch 7/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7927 - loss: 0.4337 - val_accuracy: 0.8155 - val_loss: 0.4041
# Epoch 8/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8017 - loss: 0.4219 - val_accuracy: 0.8133 - val_loss: 0.4054
# Epoch 9/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7949 - loss: 0.4313 - val_accuracy: 0.8183 - val_loss: 0.4019
# Epoch 10/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7939 - loss: 0.4338 - val_accuracy: 0.8148 - val_loss: 0.4029
# Epoch 11/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8029 - loss: 0.4239 - val_accuracy: 0.8162 - val_loss: 0.4038
# Epoch 12/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8026 - loss: 0.4282 - val_accuracy: 0.8141 - val_loss: 0.4028
# Epoch 13/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8055 - loss: 0.4202 - val_accuracy: 0.8133 - val_loss: 0.4042
# Epoch 14/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8007 - loss: 0.4193 - val_accuracy: 0.8141 - val_loss: 0.4045
# Epoch 15/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8067 - loss: 0.4175 - val_accuracy: 0.8119 - val_loss: 0.4059
# Epoch 16/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8002 - loss: 0.4176 - val_accuracy: 0.8155 - val_loss: 0.4043
# Epoch 17/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8043 - loss: 0.4170 - val_accuracy: 0.8155 - val_loss: 0.4028
# Epoch 18/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8078 - loss: 0.4127 - val_accuracy: 0.8077 - val_loss: 0.4044
# Epoch 19/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8075 - loss: 0.4096 - val_accuracy: 0.8091 - val_loss: 0.4041
# Epoch 20/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8193 - loss: 0.4021 - val_accuracy: 0.8027 - val_loss: 0.4075
# Epoch 21/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8071 - loss: 0.4163 - val_accuracy: 0.8091 - val_loss: 0.4061
# Epoch 22/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7988 - loss: 0.4194 - val_accuracy: 0.8055 - val_loss: 0.4039
# Epoch 23/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7998 - loss: 0.4170 - val_accuracy: 0.8077 - val_loss: 0.4103
# Epoch 24/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8068 - loss: 0.4054 - val_accuracy: 0.8062 - val_loss: 0.4088
# Epoch 25/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8032 - loss: 0.4144 - val_accuracy: 0.8062 - val_loss: 0.4068
# Epoch 26/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8095 - loss: 0.4088 - val_accuracy: 0.8070 - val_loss: 0.4059
# Epoch 27/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8128 - loss: 0.4049 - val_accuracy: 0.8041 - val_loss: 0.4065
# Epoch 28/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8178 - loss: 0.3940 - val_accuracy: 0.8084 - val_loss: 0.4080
# Epoch 29/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8139 - loss: 0.4068 - val_accuracy: 0.8006 - val_loss: 0.4061
# Epoch 30/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8130 - loss: 0.4055 - val_accuracy: 0.8070 - val_loss: 0.4093
# Epoch 31/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8156 - loss: 0.3998 - val_accuracy: 0.8013 - val_loss: 0.4095
# Epoch 32/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8169 - loss: 0.3890 - val_accuracy: 0.8034 - val_loss: 0.4107
# Epoch 33/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8108 - loss: 0.4060 - val_accuracy: 0.8041 - val_loss: 0.4106
# Epoch 34/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8113 - loss: 0.3965 - val_accuracy: 0.8013 - val_loss: 0.4112
# Epoch 35/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8143 - loss: 0.3962 - val_accuracy: 0.7956 - val_loss: 0.4114
# Epoch 36/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8181 - loss: 0.3948 - val_accuracy: 0.8041 - val_loss: 0.4106
# Epoch 37/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8124 - loss: 0.4074 - val_accuracy: 0.8020 - val_loss: 0.4106
# Epoch 38/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8122 - loss: 0.3996 - val_accuracy: 0.8027 - val_loss: 0.4109
# Epoch 39/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8256 - loss: 0.3867 - val_accuracy: 0.7921 - val_loss: 0.4111
# Epoch 40/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8128 - loss: 0.3990 - val_accuracy: 0.7991 - val_loss: 0.4096
# Epoch 41/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8110 - loss: 0.3972 - val_accuracy: 0.8006 - val_loss: 0.4165
# Epoch 42/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8215 - loss: 0.3928 - val_accuracy: 0.8020 - val_loss: 0.4138
# Epoch 43/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8165 - loss: 0.4015 - val_accuracy: 0.7956 - val_loss: 0.4125
# Epoch 44/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.
100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8276 - loss: 0.3655 - val_accuracy: 0.7942 - val_loss: 0.4332
# Epoch 78/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8287 - loss: 0.3714 - val_accuracy: 0.7970 - val_loss: 0.4342
# Epoch 79/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8252 - loss: 0.3709 - val_accuracy: 0.7991 - val_loss: 0.4420
# Epoch 80/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8243 - loss: 0.3688 - val_accuracy: 0.8020 - val_loss: 0.4385
# Epoch 81/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8352 - loss: 0.3595 - val_accuracy: 0.7878 - val_loss: 0.4345
# Epoch 82/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8335 - loss: 0.3649 - val_accuracy: 0.7913 - val_loss: 0.4345
# Epoch 83/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8261 - loss: 0.3634 - val_accuracy: 0.7970 - val_loss: 0.4398
# Epoch 84/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8346 - loss: 0.3639 - val_accuracy: 0.7956 - val_loss: 0.4415
# Epoch 85/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8228 - loss: 0.3732 - val_accuracy: 0.7949 - val_loss: 0.4394
# Epoch 86/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8276 - loss: 0.3718 - val_accuracy: 0.7956 - val_loss: 0.4418
# Epoch 87/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8293 - loss: 0.3662 - val_accuracy: 0.7970 - val_loss: 0.4469
# Epoch 88/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8297 - loss: 0.3565 - val_accuracy: 0.7963 - val_loss: 0.4504
# Epoch 89/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8267 - loss: 0.3731 - val_accuracy: 0.7949 - val_loss: 0.4530
# Epoch 90/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8348 - loss: 0.3594 - val_accuracy: 0.7878 - val_loss: 0.4496
# Epoch 91/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8282 - loss: 0.3612 - val_accuracy: 0.7913 - val_loss: 0.4565
# Epoch 92/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8315 - loss: 0.3674 - val_accuracy: 0.7949 - val_loss: 0.4493
# Epoch 93/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8235 - loss: 0.3697 - val_accuracy: 0.7949 - val_loss: 0.4531
# Epoch 94/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8276 - loss: 0.3637 - val_accuracy: 0.7885 - val_loss: 0.4533
# Epoch 95/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8306 - loss: 0.3556 - val_accuracy: 0.7913 - val_loss: 0.4494
# Epoch 96/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8239 - loss: 0.3568 - val_accuracy: 0.7928 - val_loss: 0.4488
# Epoch 97/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8322 - loss: 0.3671 - val_accuracy: 0.7878 - val_loss: 0.4502
# Epoch 98/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8340 - loss: 0.3588 - val_accuracy: 0.7935 - val_loss: 0.4527
# Epoch 99/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8294 - loss: 0.3534 - val_accuracy: 0.7963 - val_loss: 0.4528
# Epoch 100/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8275 - loss: 0.3648 - val_accuracy: 0.7921 - val_loss: 0.4498
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Classification Report for Neural Network with Min-Max Scaler:
#                precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      1036
#            1       0.64      0.50      0.56       373
#
#     accuracy                           0.79      1409
#    macro avg       0.73      0.70      0.71      1409
# weighted avg       0.78      0.79      0.78      1409

# %% [markdown]
# ### Deep Neural Networks

# %%
# Build the Deep Neural Network (DNN) model with Min-Max Scaler
model_dnn = Sequential()
model_dnn.add(Input(shape=(X_train_scaled.shape[1],)))
model_dnn.add(Dense(128, activation='relu'))  # First hidden layer with more neurons
model_dnn.add(Dropout(0.3))
model_dnn.add(Dense(64, activation='relu'))  # Second hidden layer
model_dnn.add(Dropout(0.3))
model_dnn.add(Dense(32, activation='relu'))  # Third hidden layer
model_dnn.add(Dropout(0.3))
model_dnn.add(Dense(16, activation='relu'))  # Fourth hidden layer
model_dnn.add(Dropout(0.3))
model_dnn.add(Dense(2, activation='softmax'))  # Output layer for binary classification

# Compile the model
model_dnn.compile(loss='categorical_crossentropy', 
                  optimizer='adam', 
                  metrics=['accuracy'])

# Train the model
history_dnn = model_dnn.fit(X_train_scaled, 
                            y_train_categorical, 
                            epochs=100, 
                            batch_size=32, 
                            validation_data=(X_test_scaled, y_test_categorical), verbose=1)

# Evaluate the model
y_pred_dnn = model_dnn.predict(X_test_scaled)
y_pred_classes_dnn = np.argmax(y_pred_dnn, axis=1)
print("Classification Report for Deep Neural Network (DNN) with Min-Max Scaler:\n", classification_report(y_test, y_pred_classes_dnn))
# Out:
# Epoch 1/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.6965 - loss: 0.5648 - val_accuracy: 0.7850 - val_loss: 0.4491
# Epoch 2/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7538 - loss: 0.4811 - val_accuracy: 0.7999 - val_loss: 0.4267
# Epoch 3/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7622 - loss: 0.4622 - val_accuracy: 0.8062 - val_loss: 0.4118
# Epoch 4/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7906 - loss: 0.4424 - val_accuracy: 0.8112 - val_loss: 0.4127
# Epoch 5/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7884 - loss: 0.4393 - val_accuracy: 0.8084 - val_loss: 0.4175
# Epoch 6/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7906 - loss: 0.4513 - val_accuracy: 0.8091 - val_loss: 0.4092
# Epoch 7/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7931 - loss: 0.4318 - val_accuracy: 0.8119 - val_loss: 0.4082
# Epoch 8/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7857 - loss: 0.4427 - val_accuracy: 0.8084 - val_loss: 0.4109
# Epoch 9/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7914 - loss: 0.4317 - val_accuracy: 0.7984 - val_loss: 0.4125
# Epoch 10/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8021 - loss: 0.4261 - val_accuracy: 0.8062 - val_loss: 0.4086
# Epoch 11/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7957 - loss: 0.4302 - val_accuracy: 0.8126 - val_loss: 0.4098
# Epoch 12/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7915 - loss: 0.4356 - val_accuracy: 0.8105 - val_loss: 0.4113
# Epoch 13/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7965 - loss: 0.4193 - val_accuracy: 0.8126 - val_loss: 0.4105
# Epoch 14/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7916 - loss: 0.4305 - val_accuracy: 0.8084 - val_loss: 0.4115
# Epoch 15/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8053 - loss: 0.4183 - val_accuracy: 0.8126 - val_loss: 0.4112
# Epoch 16/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8017 - loss: 0.4189 - val_accuracy: 0.8048 - val_loss: 0.4160
# Epoch 17/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8014 - loss: 0.4228 - val_accuracy: 0.8062 - val_loss: 0.4108
# Epoch 18/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7905 - loss: 0.4417 - val_accuracy: 0.8098 - val_loss: 0.4102
# Epoch 19/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8151 - loss: 0.4036 - val_accuracy: 0.7991 - val_loss: 0.4178
# Epoch 20/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8071 - loss: 0.4165 - val_accuracy: 0.8098 - val_loss: 0.4120
# Epoch 21/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8135 - loss: 0.4018 - val_accuracy: 0.8041 - val_loss: 0.4156
# Epoch 22/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8090 - loss: 0.4035 - val_accuracy: 0.8105 - val_loss: 0.4143
# Epoch 23/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8116 - loss: 0.4147 - val_accuracy: 0.8055 - val_loss: 0.4168
# Epoch 24/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8125 - loss: 0.4018 - val_accuracy: 0.8048 - val_loss: 0.4151
# Epoch 25/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8141 - loss: 0.4012 - val_accuracy: 0.8098 - val_loss: 0.4142
# Epoch 26/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8134 - loss: 0.4085 - val_accuracy: 0.8013 - val_loss: 0.4187
# Epoch 27/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8135 - loss: 0.3995 - val_accuracy: 0.7963 - val_loss: 0.4223
# Epoch 28/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.
100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8239 - loss: 0.3606 - val_accuracy: 0.7878 - val_loss: 0.4785
# Epoch 62/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8331 - loss: 0.3501 - val_accuracy: 0.7942 - val_loss: 0.4898
# Epoch 63/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8303 - loss: 0.3696 - val_accuracy: 0.7949 - val_loss: 0.4892
# Epoch 64/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8295 - loss: 0.3537 - val_accuracy: 0.7864 - val_loss: 0.4908
# Epoch 65/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8318 - loss: 0.3555 - val_accuracy: 0.7821 - val_loss: 0.4917
# Epoch 66/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8276 - loss: 0.3475 - val_accuracy: 0.7878 - val_loss: 0.4910
# Epoch 67/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8396 - loss: 0.3545 - val_accuracy: 0.7871 - val_loss: 0.4907
# Epoch 68/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8344 - loss: 0.3512 - val_accuracy: 0.7821 - val_loss: 0.4827
# Epoch 69/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8277 - loss: 0.3606 - val_accuracy: 0.7814 - val_loss: 0.5075
# Epoch 70/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8306 - loss: 0.3427 - val_accuracy: 0.7828 - val_loss: 0.4801
# Epoch 71/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8373 - loss: 0.3330 - val_accuracy: 0.7821 - val_loss: 0.4792
# Epoch 72/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8362 - loss: 0.3383 - val_accuracy: 0.7821 - val_loss: 0.4833
# Epoch 73/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8402 - loss: 0.3405 - val_accuracy: 0.7935 - val_loss: 0.4867
# Epoch 74/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8370 - loss: 0.3345 - val_accuracy: 0.7821 - val_loss: 0.4950
# Epoch 75/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8342 - loss: 0.3433 - val_accuracy: 0.7800 - val_loss: 0.4852
# Epoch 76/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8504 - loss: 0.3214 - val_accuracy: 0.7857 - val_loss: 0.4983
# Epoch 77/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8452 - loss: 0.3233 - val_accuracy: 0.7764 - val_loss: 0.5131
# Epoch 78/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8385 - loss: 0.3307 - val_accuracy: 0.7857 - val_loss: 0.5410
# Epoch 79/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8473 - loss: 0.3248 - val_accuracy: 0.7800 - val_loss: 0.5238
# Epoch 80/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8361 - loss: 0.3339 - val_accuracy: 0.7807 - val_loss: 0.5319
# Epoch 81/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8446 - loss: 0.3282 - val_accuracy: 0.7850 - val_loss: 0.5221
# Epoch 82/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8445 - loss: 0.3244 - val_accuracy: 0.7885 - val_loss: 0.5324
# Epoch 83/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8400 - loss: 0.3261 - val_accuracy: 0.7842 - val_loss: 0.5373
# Epoch 84/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8457 - loss: 0.3122 - val_accuracy: 0.7864 - val_loss: 0.5589
# Epoch 85/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8520 - loss: 0.3253 - val_accuracy: 0.7715 - val_loss: 0.5269
# Epoch 86/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8478 - loss: 0.3221 - val_accuracy: 0.7842 - val_loss: 0.5568
# Epoch 87/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8453 - loss: 0.3308 - val_accuracy: 0.7793 - val_loss: 0.5334
# Epoch 88/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8470 - loss: 0.3188 - val_accuracy: 0.7892 - val_loss: 0.5287
# Epoch 89/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8494 - loss: 0.3038 - val_accuracy: 0.7807 - val_loss: 0.5491
# Epoch 90/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8457 - loss: 0.3190 - val_accuracy: 0.7750 - val_loss: 0.5435
# Epoch 91/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8476 - loss: 0.3234 - val_accuracy: 0.7779 - val_loss: 0.5484
# Epoch 92/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8474 - loss: 0.3181 - val_accuracy: 0.7807 - val_loss: 0.5483
# Epoch 93/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8425 - loss: 0.3249 - val_accuracy: 0.7892 - val_loss: 0.5618
# Epoch 94/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8400 - loss: 0.3133 - val_accuracy: 0.7693 - val_loss: 0.5454
# Epoch 95/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8492 - loss: 0.3155 - val_accuracy: 0.7743 - val_loss: 0.5683
# Epoch 96/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8527 - loss: 0.3160 - val_accuracy: 0.7708 - val_loss: 0.5350
# Epoch 97/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8530 - loss: 0.3094 - val_accuracy: 0.7850 - val_loss: 0.5697
# Epoch 98/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8451 - loss: 0.3219 - val_accuracy: 0.7708 - val_loss: 0.5780
# Epoch 99/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8531 - loss: 0.3089 - val_accuracy: 0.7750 - val_loss: 0.5954
# Epoch 100/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8494 - loss: 0.3022 - val_accuracy: 0.7708 - val_loss: 0.5576
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Classification Report for Deep Neural Network (DNN) with Min-Max Scaler:
#                precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84      1036
#            1       0.56      0.64      0.60       373
#
#     accuracy                           0.77      1409
#    macro avg       0.71      0.73      0.72      1409
# weighted avg       0.78      0.77      0.78      1409

# %% [markdown]
# ### Convolutional Neural Networks

# %%
# Load your dataset
data = pd.read_csv('no_missing_values_customer_data.csv')

# Convert the target variable 'Churn' to numeric
data['Churn'] = data['Churn'].map({'Yes': 1, 'No': 0})

# Encode categorical variables using one-hot encoding
data_encoded = pd.get_dummies(data.drop(['customerID'], axis=1))

# Separate features and target
features = data_encoded.drop('Churn', axis=1)
target = data_encoded['Churn']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Apply Min-Max Scaler
scaler_minmax = MinMaxScaler()
X_train_minmax = scaler_minmax.fit_transform(X_train)
X_test_minmax = scaler_minmax.transform(X_test)

# Reshape data for CNN
X_train_cnn = X_train_minmax.reshape(X_train_minmax.shape[0], X_train_minmax.shape[1], 1)
X_test_cnn = X_test_minmax.reshape(X_test_minmax.shape[0], X_test_minmax.shape[1], 1)

# Convert labels to categorical one-hot encoding for neural network
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# %%
# Build the CNN model for tabular data
model_cnn = Sequential()
model_cnn.add(Input(shape=(X_train_cnn.shape[1], 1)))
model_cnn.add(Conv1D(filters=32, kernel_size=2, activation='relu'))
model_cnn.add(Dropout(0.3))
model_cnn.add(Conv1D(filters=64, kernel_size=2, activation='relu'))
model_cnn.add(Dropout(0.3))
model_cnn.add(Flatten())
model_cnn.add(Dense(32, activation='relu'))
model_cnn.add(Dropout(0.3))
model_cnn.add(Dense(2, activation='softmax'))

# Compile the model
model_cnn.compile(loss='categorical_crossentropy', 
                  optimizer='adam', 
                  metrics=['accuracy'])

# Train the model
history_cnn = model_cnn.fit(X_train_cnn, 
                            y_train_categorical, 
                            epochs=100, 
                            batch_size=32, 
                            validation_data=(X_test_cnn, y_test_categorical), 
                            verbose=1)

# Evaluate the model
y_pred_cnn = model_cnn.predict(X_test_cnn)
y_pred_classes_cnn = np.argmax(y_pred_cnn, axis=1)
print("Classification Report for CNN:\n", classification_report(y_test, y_pred_classes_cnn))
# Out:
# Epoch 1/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.7442 - loss: 0.4955 - val_accuracy: 0.8141 - val_loss: 0.4273
# Epoch 2/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7700 - loss: 0.4561 - val_accuracy: 0.8055 - val_loss: 0.4108
# Epoch 3/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7785 - loss: 0.4399 - val_accuracy: 0.8141 - val_loss: 0.4136
# Epoch 4/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.
100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8004 - loss: 0.4144 - val_accuracy: 0.8098 - val_loss: 0.4107
# Epoch 71/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8180 - loss: 0.4023 - val_accuracy: 0.8119 - val_loss: 0.4101
# Epoch 72/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8139 - loss: 0.3927 - val_accuracy: 0.8091 - val_loss: 0.4087
# Epoch 73/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8240 - loss: 0.3893 - val_accuracy: 0.8098 - val_loss: 0.4110
# Epoch 74/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8168 - loss: 0.4040 - val_accuracy: 0.8077 - val_loss: 0.4124
# Epoch 75/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8145 - loss: 0.4020 - val_accuracy: 0.8126 - val_loss: 0.4127
# Epoch 76/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8031 - loss: 0.4153 - val_accuracy: 0.8041 - val_loss: 0.4084
# Epoch 77/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8124 - loss: 0.4058 - val_accuracy: 0.8084 - val_loss: 0.4093
# Epoch 78/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8078 - loss: 0.4056 - val_accuracy: 0.8084 - val_loss: 0.4119
# Epoch 79/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8127 - loss: 0.3985 - val_accuracy: 0.8062 - val_loss: 0.4089
# Epoch 80/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8023 - loss: 0.4134 - val_accuracy: 0.8098 - val_loss: 0.4121
# Epoch 81/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8036 - loss: 0.4124 - val_accuracy: 0.8041 - val_loss: 0.4204
# Epoch 82/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8163 - loss: 0.3997 - val_accuracy: 0.8126 - val_loss: 0.4128
# Epoch 83/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8148 - loss: 0.4101 - val_accuracy: 0.8133 - val_loss: 0.4153
# Epoch 84/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8055 - loss: 0.4101 - val_accuracy: 0.8098 - val_loss: 0.4147
# Epoch 85/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8131 - loss: 0.3994 - val_accuracy: 0.8055 - val_loss: 0.4103
# Epoch 86/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8138 - loss: 0.3959 - val_accuracy: 0.8112 - val_loss: 0.4119
# Epoch 87/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8080 - loss: 0.4018 - val_accuracy: 0.8062 - val_loss: 0.4131
# Epoch 88/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8043 - loss: 0.3995 - val_accuracy: 0.8112 - val_loss: 0.4126
# Epoch 89/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8158 - loss: 0.3949 - val_accuracy: 0.8062 - val_loss: 0.4145
# Epoch 90/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7967 - loss: 0.4207 - val_accuracy: 0.8041 - val_loss: 0.4128
# Epoch 91/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8192 - loss: 0.3951 - val_accuracy: 0.8077 - val_loss: 0.4148
# Epoch 92/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8151 - loss: 0.3902 - val_accuracy: 0.8062 - val_loss: 0.4115
# Epoch 93/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8077 - loss: 0.4089 - val_accuracy: 0.8020 - val_loss: 0.4158
# Epoch 94/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8203 - loss: 0.4084 - val_accuracy: 0.8077 - val_loss: 0.4132
# Epoch 95/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8090 - loss: 0.4031 - val_accuracy: 0.8034 - val_loss: 0.4146
# Epoch 96/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8093 - loss: 0.4130 - val_accuracy: 0.8084 - val_loss: 0.4132
# Epoch 97/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8156 - loss: 0.3893 - val_accuracy: 0.8027 - val_loss: 0.4174
# Epoch 98/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8157 - loss: 0.3957 - val_accuracy: 0.8020 - val_loss: 0.4151
# Epoch 99/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8061 - loss: 0.4093 - val_accuracy: 0.8141 - val_loss: 0.4143
# Epoch 100/100
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8123 - loss: 0.3962 - val_accuracy: 0.8062 - val_loss: 0.4181
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Classification Report for CNN:
#                precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87      1036
#            1       0.65      0.58      0.61       373
#
#     accuracy                           0.81      1409
#    macro avg       0.75      0.73      0.74      1409
# weighted avg       0.80      0.81      0.80      1409
