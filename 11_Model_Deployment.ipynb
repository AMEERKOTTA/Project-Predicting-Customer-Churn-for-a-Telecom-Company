# %% [markdown]
# ## Model Deployment using Flask and REST API

# %% [markdown]
# **Create the Flask API for Model Deployment**
#
# **1. Load Preprocessing Objects and Model:**
#
# The label_encoders, smote object (if needed for batch processing), and trained model (optimized_tabnet_clf) are loaded at the start of the application.
#
# **2. Preprocessing Function:**
#
# + The preprocess function:
# + Applies label encoding to the incoming categorical features using the saved encoders.
# + Converts the processed data into a numpy array for input to the model.
#
# **3. API Endpoint (/predict):**
#
# + This endpoint:
# + Receives a JSON request.
# + Applies the preprocessing function to the incoming data.
# + Uses the model to predict and returns the result.

# %%
## required library
from flask import Flask, request, jsonify
import joblib
import numpy as np
from pytorch_tabnet.tab_model import TabNetClassifier

# %%
# Initialize Flask app
app = Flask(__name__)

# %%
# Load the preprocessing objects and trained model
label_encoders = joblib.load('label_encoders.pkl')
optimized_tabnet_clf = joblib.load('optimized_tabnet_model.pkl')

# %%
# Preprocessing function
def preprocess(data):
    # Apply label encoding to categorical features
    for col, le in label_encoders.items():
        if col in data:
            data[col] = le.transform([data[col]])[0]
    
    # Convert input data to numpy array
    data_array = np.array(list(data.values())).reshape(1, -1)
    
    # Apply the saved scaler or any other preprocessing (if needed)
    # Note: SMOTE is usually not applied during real-time predictions
    
    return data_array

# %%
@app.route('/predict', methods=['POST'])
def predict():
    try:
        # Get input data from the request
        input_data = request.json  # Expecting JSON input
        preprocessed_data = preprocess(input_data)

        # Make prediction using the model
        prediction = optimized_tabnet_clf.predict(preprocessed_data)

        # Return prediction result as JSON
        return jsonify({'prediction': int(prediction[0])})
    except Exception as e:
        return jsonify({'error': str(e)})

if __name__ == '__main__':
    app.run(host='0.0.0.0', port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.70.221:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [09/Sep/2024 15:11:36] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:15] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:17] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:19] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:21] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:23] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:25] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:27] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:30] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:32] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:34] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:36] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:38] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:40] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:42] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:46] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:48] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:50] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:52] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:54] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:56] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:13:59] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:01] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:03] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:05] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:07] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:09] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:11] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:13] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:15] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:17] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:19] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:22] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:24] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:26] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:28] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:30] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:32] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:34] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:36] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:38] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:40] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:43] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:47] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:49] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:51] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:53] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:55] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:57] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:14:59] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:01] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:03] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:05] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:08] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:10] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:12] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:14] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:16] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:18] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:20] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:22] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:24] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:26] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:28] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:30] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:32] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:34] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:36] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:39] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:41] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:43] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:47] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:49] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:51] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:53] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:55] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:57] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:15:59] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:01] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:04] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:06] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:08] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:10] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:12] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:14] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:16] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:18] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:20] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:22] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:24] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:26] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:29] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:31] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:33] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:35] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:37] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:39] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:16:41] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:17:29] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:17:31] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:17:33] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:17:35] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:17:37] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:17:39] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:17:41] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:17:43] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:17:45] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:17:47] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:17:49] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:17:52] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:17:54] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:17:56] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:17:58] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:00] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:02] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:04] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:06] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:08] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:10] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:12] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:14] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:17] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:19] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:21] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:23] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:25] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:27] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:29] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:31] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:33] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:35] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:37] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:39] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:41] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:43] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:46] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:48] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:50] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:52] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:54] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:56] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:18:58] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:00] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:02] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:04] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:06] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:08] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:10] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:12] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:15] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:17] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:19] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:21] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:23] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:25] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:27] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:29] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:31] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:33] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:35] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:37] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:39] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:42] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:46] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:48] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:50] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:52] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:54] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:56] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:19:58] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:00] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:02] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:04] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:07] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:09] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:11] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:13] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:15] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:17] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:19] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:21] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:23] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:25] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:27] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:29] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:31] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:34] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:36] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:38] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:40] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:42] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:44] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:46] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:48] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:50] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:52] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2024 15:20:54] "POST /predict HTTP/1.1" 200 -
